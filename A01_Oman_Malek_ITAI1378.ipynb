# %% [markdown]
# <a href="https://colab.research.google.com/github/malekoman14-ship-it/jupyter-exploration/blob/main/A01_Oman_Malek_ITAI1378.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# "My first markdown cell in Jupyter"
# ---

# %%
print("Hello, World!")
# Out:
# Hello, World!
